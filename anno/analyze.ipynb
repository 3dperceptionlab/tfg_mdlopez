# %%
# read biovid_ds_train.csv, biovid_ds_val.csv, biovid_ds_test.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# read data
train_df = pd.read_csv('biovid_ds_train.csv', sep=' ', header=None)
val_df = pd.read_csv('biovid_ds_val.csv', sep=' ', header=None)
test_df = pd.read_csv('biovid_ds_test.csv', sep=' ', header=None)

# %%
# create a function to plot the distribution of labels
def plot_distribution(df, title):
    df[1].value_counts().plot(kind='bar')
    plt.title(title)
    plt.xlabel('Clase')
    plt.ylabel('Número de muestras')
    plt.show()

# %%
# plot the distribution of labels
plot_distribution(train_df, 'Distribución de clases en el conjunto de entrenamiento')

# %%
# val_df
plot_distribution(val_df, 'Distribución de clases en el conjunto de validación')

# %%
# test
plot_distribution(test_df, 'Distribución de clases en el conjunto de test')
